# %%
# Importing necessary libraries for data manipulation and visualization
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("UberDataset.csv")  # Load the dataset

# %%
dataset
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
dataset.shape
# Out:
# (1156, 7)

# %%
dataset.info() # Initial data exploration
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# # Data Preprocessing

# %%
dataset['PURPOSE'].fillna('NOT' , inplace = True) # Handle missing values in PURPOSE column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dataset['PURPOSE'].fillna('NOT' , inplace = True)
#
# NameError: name 'dataset' is not defined

# %%
dataset.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NOT
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
# Convert date columns to datetime format

dataset['START_DATE'] = pd.to_datetime(dataset['START_DATE'] , errors = 'coerce')
dataset['END_DATE'] = pd.to_datetime(dataset['END_DATE'] , errors = 'coerce')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
#  7   DATE        421 non-null    object
#  8   TIME        421 non-null    float64
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 81.4+ KB

# %%
# Feature engineering: Extract date and time components
from datetime import datetime
dataset['DATE'] = pd.DatetimeIndex(dataset['START_DATE']).date
dataset['TIME'] = pd.DatetimeIndex(dataset['START_DATE']).hour

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0

# %%
# Remove a single column
dataset = dataset.drop('date', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Remove a single column
# ----> 2 dataset = dataset.drop('date', axis=1)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0

# %%
# Create time-based categorical feature
dataset['DAY-NIGHT'] = pd.cut(x=dataset['TIME'], bins = (0,10,15,19,24) , labels=['Morning' , 'Afternoon' ,'Evening' , 'Night'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
#  7   DATE        421 non-null    object
#  8   TIME        421 non-null    float64
#  9   DAY-NIGHT   414 non-null    category
# dtypes: category(1), datetime64[ns](2), float64(2), object(5)
# memory usage: 82.7+ KB

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY-NIGHT
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon

# %%
dataset.dropna(inplace = True)

# %%
dataset.shape
# Out:
# (413, 10)

# %% [markdown]
# # Data Visualization

# %%
# Creating visualizations to explore the data (in which category and purpose do people book the most Uber rides )
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
sns.countplot(dataset['CATEGORY'])
plt.xticks(rotation  = 90)

plt.subplot(1,2,2)
sns.countplot(dataset['PURPOSE'])
# Out:
# <Axes: xlabel='count', ylabel='PURPOSE'>

# %% [raw]
# The Business category seems to dominate Uber bookings compared to the Personal category. This is evident from the bar
# plot or distribution that compares the counts of rides in these categories.
#
# People primarily book Uber rides for Meetings purposes, which shows the highest count in your purpose-based bar graph. Other notable purposes could be Meals/Entertainment.

# %%
# Creating visualizations to explore the data
sns.countplot(dataset['DAY-NIGHT'])
# Out:
# <Axes: xlabel='count', ylabel='DAY-NIGHT'>

# %% [raw]
# From the time-based visualization, evening hours (e.g., between 5 PM and 8 PM) are when people book cabs the most. There may also be a secondary peak during morning hours for commute-related rides.

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY-NIGHT
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon

# %%
# Extract the month from the 'START_DATE' column and create a new column 'MONTH'
dataset['MONTH'] = pd.DatetimeIndex(dataset['START_DATE']).month
month_label = {1.0 : 'Jan',2.0 : 'Feb',3.0 : 'Mar',4.0 : 'Apr',5.0 : 'May',6.0 : 'Jun',7.0 : 'Jul',8.0 : 'Aug',
               9.0 : 'Seb',10.0 : 'Oct',11.0 : 'Nov',12.0 : 'Dec'}

dataset['MONTH'] = dataset.MONTH.map(month_label)       

mon = dataset.MONTH.value_counts(sort =False)

# %%
dataset.tail()
# Out:
#               START_DATE            END_DATE  CATEGORY        START  \
# 1043 2016-12-12 13:22:00 2016-12-12 13:32:00  Business         Cary
# 1044 2016-12-12 13:36:00 2016-12-12 13:51:00  Business         Cary
# 1045 2016-12-12 14:26:00 2016-12-12 14:39:00  Business         Apex
# 1046 2016-12-12 17:51:00 2016-12-12 18:01:00  Business         Cary
# 1047 2016-12-12 20:48:00 2016-12-12 20:57:00  Business  Morrisville
#
#              STOP  MILES          PURPOSE        DATE  TIME  DAY-NIGHT MONTH
# 1043         Cary    3.1  Errand/Supplies  2016-12-12  13.0  Afternoon   Dec
# 1044         Apex    4.4   Meal/Entertain  2016-12-12  13.0  Afternoon   Dec
# 1045         Cary    4.7   Customer Visit  2016-12-12  14.0  Afternoon   Dec
# 1046  Morrisville    3.0   Meal/Entertain  2016-12-12  17.0    Evening   Dec
# 1047         Cary    3.0   Customer Visit  2016-12-12  20.0      Night   Dec

# %%
# Create a DataFrame with months and the maximum 'MILES' value for each month
df = pd.DataFrame({ "MONTH": mon.values , 
              "Value count" : dataset.groupby('MONTH', sort =False)['MILES'].max() })

# Create a line plot using Seaborn to visualize the data
p = sns.lineplot(data =df)
p.set(xlabel="MONTH" , ylabel = "Value count")
# Out:
# [Text(0.5, 0, 'MONTH'), Text(0, 0.5, 'Value count')]

# %% [raw]
# The graph indicates that the least number of bookings occur in months like July or August
# (or other months with lower bars on your monthly distribution plot). This suggests a seasonal dip in ride demand during those times.

# %%
# Convert datetime to weekday numbers (Monday=0 to Sunday=6)
dataset['DAY'] =dataset.START_DATE.dt.weekday
day_label = { 0: "Mon", 1 : "Tue" , 2 : "Wed" , 3: "Thr" , 4: "Fri", 5: "Sat" , 6:"Sun"}
dataset['DAY'] = dataset['DAY'].map(day_label)

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY-NIGHT MONTH  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night   Jan
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning   Jan
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night   Jan
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening   Jan
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon   Jan
#
#    WEEK  DAY
# 0     1  Fri
# 1     2  Sat
# 2     2  Sat
# 3     5  Tue
# 4     6  Wed

# %%
# Get the count of each unique value in the 'DAY' column of the dataset
day_label = dataset.DAY.value_counts()

# Create a bar plot using seaborn
sns.barplot(x = day_label.index , y = day_label )
plt.xlabel('DAY')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %% [raw]
# Friday appear to be the busiest day for Uber rides based on weekday distribution.

# %%
# Create a box plot for the 'MILES' column to visualize its distribution and identify any outliers.
sns.boxplot(dataset['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.boxplot(dataset[dataset['MILES'] <100]['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.distplot(dataset[dataset['MILES'] <40 ] ['MILES'])
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_30648\2551406915.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset[dataset['MILES'] <40 ] ['MILES'])
# <Axes: xlabel='MILES', ylabel='Density'>

# %% [raw]
# From distance-related visualizations majority of rides fall under 5 to 10 miles

# %% [markdown]
# # Insights

# %% [raw]
# Most Popular Booking Category : Business dominates Uber bookings compared to Personal rides.
#
# Primary Ride Purpose : Meetings is the most frequent purpose, followed by Meals/Entertainment
#
# Peak Booking Times : Evening hours (5 PM – 8 PM) show the highest demand, with a secondary morning commute peak.
#
# Low-Demand Months : Fewest bookings occur in July/August, indicating a seasonal dip in ridership.
#
# Busiest Days of the Week : Friday is the peak day,likely tied to work commutes or weekend plans.
#
# Typical Ride Distance : Most trips are short-distance (5–10 miles), with fewer rides exceeding 20 miles.
